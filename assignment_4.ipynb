# %%
# 4-1. Guest List: If you could invite anyone, living or deceased, to dinner, who
# would you invite? Make a list that includes at least three people you’d like to
# invite to dinner. Then use your list to print a message to each person, inviting
# them to dinner.

# %%
guests = ["Saim", "Moiz", "Ali"]

for guest in guests:
    print(f"Dear {guest},\n"
          "you're invited for dinner at my place"
          "\n"
          "Sincerely,\n"
          "[Muhammad Saim]")
# Out:
# Dear Saim,
# you're invited for dinner at my place
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# you're invited for dinner at my place
# Sincerely,
# [Muhammad Saim]
# Dear Ali,
# you're invited for dinner at my place
# Sincerely,
# [Muhammad Saim]

# %%
# 4-2. Changing Guest List: You just heard that one of your guests can’t make the
# dinner, so you need to send out a new set of invitations. You’ll have to think of
# someone else to invite.
#• Start with your program from Exercise 4-1. Add a print statement at the
# end of your program stating the name of the guest who can’t make it. 
#• Modify your list, replacing the name of the guest who can’t make it with
# the name of the new person you are inviting. 
#• Print a second set of invitation messages, one for each person who is still
# in your list.

# %%
guests = ["Saim", "Moiz", "Ali"]

for guest in guests:
    print(f"Dear {guest},\n"
          "you're invited for dinner at my place"
          "\n"
          "Sincerely,\n"
          "[Muhammad Saim]")

print(f"\n{guests[2]} can't make it to dinner.")
guests[2] = "Ahmed"
print("\nNew invitations:\n")
for guest in guests:
    print(f"Dear {guest},\n"
          "you're invited for dinner at my place.\n"
          "Sincerely,\n"
          "[Muhammad Saim]")
# Out:
# Dear Saim,
# you're invited for dinner at my place
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# you're invited for dinner at my place
# Sincerely,
# [Muhammad Saim]
# Dear Ali,
# you're invited for dinner at my place
# Sincerely,
# [Muhammad Saim]
#
# Ali can't make it to dinner.
#
# New invitations:
#
# Dear Saim,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Ahmed,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]

# %%
# 4-3. More Guests: You just found a bigger dinner table, so now more space is
# available. Think of three more guests to invite to dinner.
# •     Start with your program from Exercise 4-1 or Exercise 4-2. Add a print
# statement to the end of your program informing people that you found a
# bigger dinner table. 
# •     Use insert() to add one new guest to the beginning of your list. 
# •     Use insert() to add one new guest to the middle of your list. 
# •     Use append() to add one new guest to the end of your list.

# %%
guests = ["Saim", "Moiz", "Ahmed"]

# Initial invitations
print("Initial invitations:")
for guest in guests:
    print(f"Dear {guest},\n"
          "you're invited for dinner at my place.\n"
          "Sincerely,\n"
          "[Muhammad Saim]")

print("\nFound a bigger table!")

# Add three more guests
guests.insert(0, "abc")
guests.insert(2, "pqr")
guests.append("xyz")

# New invitations
print("\nNew invitations:")
for guest in guests:
    print(f"Dear {guest},\n"
          "ypu're invited for dinner at my place.\n"
          "Sincerely,\n"
          "[Muhammad Saim]")
# Out:
# Initial invitations:
# Dear Saim,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Ahmed,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
#
# Found a bigger table!
#
# New invitations:
# Dear abc,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Saim,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear pqr,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Ahmed,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear xyz,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]

# %%
# 4-4. Shrinking Guest List: You just found out that your new dinner table won’t
# arrive in time for the dinner, and you have space for only two guests. 
# •     Start with your program from Exercise 4-3. Add a new line that prints a
# message saying that you can invite only two people for dinner. 
# •     Use pop() to remove guests from your list one at a time until only two
# names remain in your list. Each time you pop a name from your list, print
# a message to that person letting them know you’re sorry you can’t invite
# them to dinner. 
# •     Print a message to each of the two people still on your list, letting them
# know they’re still invited. 
# •     Use del to remove the last two names from your list, so you have an empty
# list. Print your list to make sure you actually have an empty list at the end
# of your program.

# %%
guests = ["Saim","Moiz", "Ahmed"]

# Initial invitations
print("Initial invitations:")
for guest in guests:
    print(f"Dear {guest},\n"
          "you're invited for dinner at my place.\n"
          "Sincerely,\n"
          "[Muhammad Saim]")

print("\nFound a bigger table!")

# Add three more guests
guests.insert(0, "abc")
guests.insert(2, "pqr")
guests.append("xyz")

# New invitations
print("\nNew invitations:")
for guest in guests:
    print(f"Dear {guest},\n"
          "ypu're invited for dinner at my place.\n"
          "Sincerely,\n"
          "[Muhammad Saim]")


print("\nUnfortunately, the new dinner table won't arrive in time.")
print("I can only invite two people for dinner.")

# Remove guests until only two remain
while len(guests) > 2:
    removed_guest = guests.pop()
    print(f"Dear {removed_guest},\n"
          "I am so sorry to inform you that I am unable to invite you to dinner due to unforeseen circumstances.\n"
          "Sincerely,\n"
          "[Muhammad Saim]")

print("\nInvitations to the remaining guests:")
for guest in guests:
    print(f"Dear {guest},\n"
          "You are still invited to dinner!\n"
          "Sincerely,\n"
          "[Muhammad Saim]")

# Remove the last two guests
del guests[0]
del guests[0]

print("\nEmpty guest list:", guests)
# Out:
# Initial invitations:
# Dear Saim,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Ahmed,
# you're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
#
# Found a bigger table!
#
# New invitations:
# Dear abc,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Saim,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear pqr,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Moiz,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear Ahmed,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
# Dear xyz,
# ypu're invited for dinner at my place.
# Sincerely,
# [Muhammad Saim]
#
# Unfortunately, the new dinner table won't arrive in time.
# I can only invite two people for dinner.
# Dear xyz,
# ...

# %%
fruits = ["apple", "banana", "orange", "grape", "kiwi", "mango", "strawberry", "pineapple"]

# Indexing
print("First fruit:", fruits[0])
print("Last fruit:", fruits[-1])

# Slicing
print("First three fruits:", fruits[:3])
print("Fruits from index 3 to 5:", fruits[3:6])
print("Every other fruit:", fruits[::4])
print("Reversed list:", fruits[::-1])
# Out:
# First fruit: apple
# Last fruit: pineapple
# First three fruits: ['apple', 'banana', 'orange']
# Fruits from index 3 to 5: ['grape', 'kiwi', 'mango']
# Every other fruit: ['apple', 'kiwi']
# Reversed list: ['pineapple', 'strawberry', 'mango', 'kiwi', 'grape', 'orange', 'banana', 'apple']
